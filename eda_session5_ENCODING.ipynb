# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\jayavardhan\Downloads\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
winequality_df=pd.read_csv(r"C:\Users\jayavardhan\Downloads\winequality_red.csv")

# %% [markdown]
# **Data LifeCycle**
# - data read
# - data cleaning
# - data analysis
# - feature engineering
# - feature selection
# - model development
# - model evaluation
# - model tuning
# - model deployment

# %% [markdown]
# **Feature Engineering**
# - so far we have performed feature engineering
#     - Data Frame quick checks
#     - categorical column analysis
#     - Bar charts, Pie charts
#     - numerical column analysis
#     - histogram , box plots, outliers
#     - Bi-Multi variate analysis
#     - correlation etc..,
# - now we need to learn feature Engineering
#     - we will create a new columns for better ML models
#     - we will perform the **Encoding** ,which is convert categorical to numerical data
#     - we will do data **transformations**
#     - we will perform **Scaling: Standardization and Normalization**
#     - we will perform **Missing value analysis**
# - Simply feature enginnering means our data will not be modified

# %%
winequality_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# **Case Status**

# %%
#first check how many unique llabels are there in case status
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# create a dictionart
d={'Certified':0,'Denied':1}

# %%
# map the above dictionaru with the original column
visa_df['case_status']=visa_df['case_status'].map(d)

# %%
visa_df['case_status']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
labels=sorted(visa_df['education_of_employee'].unique())
e={j:i for i,j in enumerate(labels)}
visa_df['education_of_employee'].map(e)
# Out:
# 0        2
# 1        3
# 2        0
# 3        0
# 4        3
#         ..
# 25475    0
# 25476    2
# 25477    3
# 25478    3
# 25479    0
# Name: education_of_employee, Length: 25480, dtype: int64

# %% [markdown]
# - there are two types of Encoders
#     - LabelEncoder
#     - OrdinalEncoder

# %%
Education       LabelEncoder     OrdinalEncoder
====================================================
HighSchool          1                  0

Bachelor            0                  1

Master              2                  2

Ph.D                3                  3

1 0 2 3 ===> ML model sees this: 3>2>1>0
which indicates: Ph,D > Master > HighSchool > bachelors    #which is wrong

# %%
visa_df=pd.read_csv(r"C:\Users\jayavardhan\Downloads\Visadataset - Visadataset.csv")

# %%
- sklearn: **package**
    - preprocessing: **module**
        - LabelEncoder: **class**
             - fit_transform: **method**

import sklearn
sklearn.preprocessing

from sklearn import preprocessing


from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform()

# #steps: read the class
#         save the class
#         apply fit_transform

# %% [markdown]
# **fit transform**

# %% [markdown]
# - fit: Created a dictionary(find something)
# - transform: using above finding we are modify the data
#
#
#
# from sklearn.module import class
#
# va=class()
#
# va.fit()  va.fit_transform

# %% [markdown]
# **Label ENCODER**

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform(visa_df['case_status'])
# Out:
# array([1, 0, 1, ..., 0, 0, 0], shape=(25480,))

# %%
num=visa_df.select_dtypes(exclude='object').columns
cat=visa_df.select_dtypes(include='object').columns

# %%
#read the data again
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat[1:]:
    visa_df[i]=le.fit_transform(visa_df[i])

# %%
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
for i in cat[1:]:
    visa_df[i]=oe.fit_transform(visa_df[[i]])

# %%
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01        1.0                    2.0                 0.0
# 1         EZYV02        1.0                    3.0                 1.0
# 2         EZYV03        1.0                    0.0                 0.0
# 3         EZYV04        1.0                    0.0                 0.0
# 4         EZYV05        0.0                    3.0                 1.0
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476        1.0                    0.0                 1.0
# 25476  EZYV25477        1.0                    2.0                 1.0
# 25477  EZYV25478        1.0                    3.0                 1.0
# 25478  EZYV25479        1.0                    3.0                 1.0
# 25479  EZYV25480        1.0                    0.0                 1.0
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# **pd.get_dummies**

# %%
visa_df=pd.read_csv(r"C:\Users\jayavardhan\Downloads\Visadataset - Visadataset.csv")

# %%
- get dummies is a way to represent the categorical columns to numerical only
- first it will check what are the lebels in a column
- for example case status has two labels
    - Denied and Certified
- so it will create two new columns based on labels
    - col1: case_status_Denied
    - col2: case_status_Certified


 case_status  |     case_status_Denied   |    case_status_Certified
     -        |              -           |           -             
  Denied      |              1           |           0
  Certified   |              0           |           1
  Certified   |              0           |           1


**It is also called 
- It makes

# %%
pd.get_dummies(visa_df['case_status'],
               dtype=int)
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]
