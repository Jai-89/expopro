# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **How to create a null values in a data**

# %% [markdown]
# - None
# - np.nan

# %%
d={'Names':['Ramesh','Suresh',None,'Sathish'],
   'Age':[None,20,21,24],
   'City':['Hyd','Blr','Pune',None]}
df=pd.DataFrame(d)
df
# Out:
#      Names   Age  City
# 0   Ramesh   NaN   Hyd
# 1   Suresh  20.0   Blr
# 2     None  21.0  Pune
# 3  Sathish  24.0  None

# %%
df.to_csv('data1.csv',index=False)

# %%
d={'Names':['Ramesh','Suresh',np.nan,'Sathish'],
   'Age':[np.nan,20,21,24],
   'City':['Hyd','Blr','Pune',np.nan]}
df2=pd.DataFrame(d)
df2
df2.to_csv('data2.csv',index=False)

# %% [markdown]
# - categorical data use **None**
# - numerical data use **np.nan**

# %%
df.isnull()
# isnull = whereever null value is there it displays as true
# Out:
#    Names    Age   City
# 0  False   True  False
# 1  False  False  False
# 2   True  False  False
# 3  False  False   True

# %%
df.isnull().sum()
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %%
df.values
# Out:
# array([['Ramesh', nan, 'Hyd'],
#        ['Suresh', 20.0, 'Blr'],
#        [None, 21.0, 'Pune'],
#        ['Sathish', 24.0, None]], dtype=object)

# %%
df.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# dtype: object

# %% [markdown]
# **Fill the values**

# %%
df.fillna(30)
# it is a random values
# Out:
#      Names   Age  City
# 0   Ramesh  30.0   Hyd
# 1   Suresh  20.0   Blr
# 2       30  21.0  Pune
# 3  Sathish  24.0    30

# %%
df
# Out:
#      Names   Age  City
# 0   Ramesh   NaN   Hyd
# 1   Suresh  20.0   Blr
# 2     None  21.0  Pune
# 3  Sathish  24.0  None

# %%
# select the column and fill with value
df['Age'].fillna(30)
# Out:
# 0    30.0
# 1    20.0
# 2    21.0
# 3    24.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(df['Age'].mean())

# %%
#pad,ffill,bfill,backfill
#axis=0,axis=1
df.fillna(method='pad')
# Out:
# C:\Users\jayavardhan\AppData\Local\Temp\ipykernel_26200\2927640253.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#      Names   Age  City
# 0   Ramesh   NaN   Hyd
# 1   Suresh  20.0   Blr
# 2   Suresh  21.0  Pune
# 3  Sathish  24.0  Pune

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\jayavardhan\AppData\Local\Temp\ipykernel_26200\1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#      Names   Age  City
# 0   Ramesh   NaN   Hyd
# 1   Suresh  20.0   Blr
# 2   Suresh  21.0  Pune
# 3  Sathish  24.0  Pune

# %%
df.fillna(method='bfill')
# Out:
# C:\Users\jayavardhan\AppData\Local\Temp\ipykernel_26200\2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#      Names   Age  City
# 0   Ramesh  20.0   Hyd
# 1   Suresh  20.0   Blr
# 2  Sathish  21.0  Pune
# 3  Sathish  24.0  None

# %%
df.fillna(method='backfill')
# Out:
# C:\Users\jayavardhan\AppData\Local\Temp\ipykernel_26200\340531938.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='backfill')
#      Names   Age  City
# 0   Ramesh  20.0   Hyd
# 1   Suresh  20.0   Blr
# 2  Sathish  21.0  Pune
# 3  Sathish  24.0  None

# %%
df.fillna(df['City'].bfill())
# Out:
#      Names   Age  City
# 0   Ramesh   NaN   Hyd
# 1   Suresh  20.0   Blr
# 2     None  21.0  Pune
# 3  Sathish  24.0  None

# %%
df.fillna(method='bfill',axis=1)
# Out:
# C:\Users\jayavardhan\AppData\Local\Temp\ipykernel_26200\3381026564.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',axis=1)
#      Names   Age  City
# 0   Ramesh   Hyd   Hyd
# 1   Suresh  20.0   Blr
# 2     21.0  21.0  Pune
# 3  Sathish  24.0  None

# %%
df
# Out:
#      Names   Age  City
# 0   Ramesh   NaN   Hyd
# 1   Suresh  20.0   Blr
# 2     None  21.0  Pune
# 3  Sathish  24.0  None

# %%
df['Age'].fillna(round(df['Age'].mean(),1))
# Out:
# 0    21.7
# 1    20.0
# 2    21.0
# 3    24.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(df['Age'].median())
# Out:
# 0    21.0
# 1    20.0
# 2    21.0
# 3    24.0
# Name: Age, dtype: float64

# %%
#there is no particular rules to fill null values
#It is completely based on situation

# %%
Gender=['male','female',None,'male']
df=pd.DataFrame(Gender)
df
# Out:
#         0
# 0    male
# 1  female
# 2    None
# 3    male

# %%
df.fillna(df[0].mode())
# Out:
#         0
# 0    male
# 1  female
# 2    male
# 3    male

# %%
d={'Names':['Ramesh','Suresh','Ramesh','Sathish'],
   'Age':[21,20,21,24],
   'City':['Hyd','Blr','Hyd','pune']}
df=pd.DataFrame(d)
df
# Out:
#      Names  Age  City
# 0   Ramesh   21   Hyd
# 1   Suresh   20   Blr
# 2   Ramesh   21   Hyd
# 3  Sathish   24  pune

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop(2)
# Out:
#      Names  Age  City
# 0   Ramesh   21   Hyd
# 1   Suresh   20   Blr
# 3  Sathish   24  pune

# %% [markdown]
# **KNNImputer**

# %% [markdown]
# - KNN : K-nearest neighbours
# - where k is a number
# - insted of taking avg of all the values data
#     - first will find the neighbours who are close with missing data
#     - by using euclidian distance calculation will identify the neighbours rows
#     - suppose k=2 will identify two closeset rows
#     - those closest row values will take it will calculate the mean
#     - finally will fill with the mean

# %%
salary=[50000,np.nan,70000,90000]
age=[25,28,30,40]
df=pd.DataFrame(zip(salary,age),columns=['Salary','Age'])
df
# Out:
#     Salary  Age
# 0  50000.0   25
# 1      NaN   28
# 2  70000.0   30
# 3  90000.0   40

# %%
from sklearn.impute import KNNImputer
kn=KNNImputer(n_neighbors=2)
pd.DataFrame(kn.fit_transform(df))
# Out:
#          0     1
# 0  50000.0  25.0
# 1  60000.0  28.0
# 2  70000.0  30.0
# 3  90000.0  40.0
